# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.datasets import load_diabetes

# %%
# Load the dataset (House Price dataset from OpenML)
diabetes = load_diabetes()
x=pd.DataFrame(diabetes.data,columns=diabetes.feature_names)
y=pd.Series(diabetes.target,name="target")
diabetes_df=pd.concat([x,y],axis=1)
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
print(diabetes_df.isnull().sum())
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Initialize the ElasticNet model
elastic_net = ElasticNet(alpha=0.01, l1_ratio=0.9,random_state=42)  # l1_ratio=0.5 means equal weight on L1 and L2

# %%
# Train the model
elastic_net.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.01, l1_ratio=0.9, random_state=42)

# %%
# Make predictions on the test set
y_pred = elastic_net.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 2877.332423745628
