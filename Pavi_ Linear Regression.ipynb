# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\pavit\Documents\Height_weight.csv") #or pd.read_csv(r"paste path") no need o type double slash

# %%
df
# Out:
#     Height  Weight
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %%
plt.scatter(df["Weight(Pounds)"],df["Height(Inches)"])
plt.xlabel("weight")
plt.ylabel("height")
# Out:
# Text(0, 0.5, 'height')

# %%
df.corr()
# Out:
#                    Index  Height(Inches)  Weight(Pounds)
# Index           1.000000        0.009626       -0.007257
# Height(Inches)  0.009626        1.000000        0.502859
# Weight(Pounds) -0.007257        0.502859        1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
x = df[["Weight(Pounds)"]]
x
# Out:
#        Weight(Pounds)
# 0            112.9925
# 1            136.4873
# 2            153.0269
# 3            142.3354
# 4            144.2971
# ...               ...
# 24995        118.0312
# 24996        120.1932
# 24997        118.2655
# 24998        132.2682
# 24999        124.8742
#
# [25000 rows x 1 columns]

# %%
x.shape
# Out:
# (25000, 1)

# %%
y=df["Height(Inches)"]
y
# Out:
# 0        65.78331
# 1        71.51521
# 2        69.39874
# 3        68.21660
# 4        67.78781
#            ...
# 24995    69.50215
# 24996    64.54826
# 24997    64.69855
# 24998    67.52918
# 24999    68.87761
# Name: Height(Inches), Length: 25000, dtype: float64

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
#        Weight(Pounds)
# 6920         128.0357
# 17926        115.5202
# 1123         132.8885
# 4518         120.5416
# 5576         122.7718
# ...               ...
# 21575        111.5242
# 5390         123.4431
# 860          120.9809
# 15795        135.6468
# 23654        122.7826
#
# [18750 rows x 1 columns]

# %%
y_train
# Out:
# 6920     69.97280
# 17926    65.59616
# 1123     65.24285
# 4518     67.80062
# 5576     70.50871
#            ...
# 21575    67.48875
# 5390     66.92527
# 860      68.39347
# 15795    69.29711
# 23654    67.12804
# Name: Height(Inches), Length: 18750, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(x_train)
# Out:
# array([[ 0.08310666],
#        [-0.99311816],
#        [ 0.50040551],
#        ...,
#        [-0.52354516],
#        [ 0.73759547],
#        [-0.36861454]])

# %%
scaler.transform(y_train)
# Out:
# C:\Users\pavit\anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4448/2198850222.py in <module>
# ----> 1 scaler.transform(y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#     971
#     972         copy = copy if copy is not None else self.copy
# --> 973         X = self._validate_data(
#     974             X,
#     975             reset=False,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     559             raise ValueError("Validation should be done on X, y or both.")
#     560         elif not no_val_X and no_val_y:
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression

# %%
regression.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4448/4127345435.py in <module>
# ----> 1 regression.fit(x_train,y_train)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
regression.coef()
regression.intercept()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4448/160993406.py in <module>
# ----> 1 regression.coef()
#       2 regression.intercept()
#
# AttributeError: type object 'LinearRegression' has no attribute 'coef'

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,regression.predict(x_train))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4448/2708170436.py in <module>
#       1 plt.scatter(x_train,y_train)
# ----> 2 plt.plot(x_train,regression.predict(x_train))
#
# TypeError: predict() missing 1 required positional argument: 'X'

# %%
# prediction of testing data
# predicted height = intercept+coef_(weights)
# y_pred_test_data= 80.5+1.04(x_test)

# %%
# prediction of testing data
y_pred = regression.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4448/2535033601.py in <module>
#       1 # prediction of testing data
# ----> 2 y_pred = regression.predict(x_test)
#
# TypeError: predict() missing 1 required positional argument: 'X'
