# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ADMIN\Shalini Files\datasets\insurance_data.csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker="+",color="red")

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[["age"]],df.bought_insurance,test_size=0.1)

# %%
x_train
# Out:
#     age
# 23   45
# 9    61
# 12   27
# 0    22
# 24   50
# 5    56
# 14   49
# 15   55
# 21   26
# 10   18
# 1    25
# 11   28
# 22   40
# 4    46
# 16   25
# 20   21
# 8    62
# 6    55
# 13   29
# 17   58
# 19   18
# 25   54
# 2    47
# 3    52

# %%
x_test
# Out:
#     age
# 18   19
# 7    60
# 26   23

# %%
y_test
# Out:
# 18    0
# 7     1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 0], dtype=int64)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.92192513, 0.07807487],
#        [0.06123456, 0.93876544],
#        [0.87670714, 0.12329286]])

# %%
import seaborn as sns
sns.regplot(x="age",y="bought_insurance",data=df,logistic=True,ci=None)
# Out:
# <Axes: xlabel='age', ylabel='bought_insurance'>
